# %%
import pandas as pd 
import numpy as np
from __future__ import unicode_literals
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Editing the data a bit
kick_data = pd.read_csv("/Users/briankalinowski/Kickstarter-Data-Analysis/most_backed.csv")

del kick_data['Unnamed: 0']

# %%
kick_data.rename(columns = {'amt.pledged' : 'pledged_amount'}, inplace=True)
kick_data.rename(columns = {'pledge.tier' : 'pledge_tier'}, inplace=True)
kick_data.rename(columns = {'num.backers' : 'backers'}, inplace=True)
kick_data.rename(columns = {'num.backers.tier' : 'backers_by_tier'}, inplace=True)
kick_data.rename(columns = {'blurb' : 'pitch'}, inplace=True)


kick_usd = kick_data.loc[kick_data['currency'] == 'usd']

kick_tiers = [len(row.split()) for row in kick_usd['pledge_tier']]

kick_data['num_tiers'] = pd.Series(kick_tiers, index = kick_usd.index)

# %%
kick_data.to_csv('Kick_funded.csv')

# %%
# Reading in the data
kick_data = pd.read_csv("/Users/briankalinowski/Kickstarter-Data-Analysis/Kick_funded.csv")
del kick_data['Unnamed: 0']

# %%
#4000 of the most funded campaigns that were on Kickstarter.
kick_data.head(100)
# Out:
#     pledged_amount                                              pitch  \
# 0        8782571.0  \nThis is a card game for people who are into ...
# 1        6465690.0  \nAn unusually addicting, high-quality desk to...
# 2        5408916.0  \nBring Reading Rainbow’s library of interacti...
# 3        5702153.0  \nUPDATED: This is it. We're making a Veronica...
# 4        3336371.0  \nAn adventure game from Tim Schafer, Double F...
# 5       20338986.0  \nColor e-paper smartwatch with up to 7 days o...
# 6        4188927.0  \nA story-driven CRPG set in the world of Mont...
# 7        3986929.0  \nPillars of Eternity is an isometric, party-b...
# 8        2090104.0  \nThe creative talent behind Banjo-Kazooie and...
# 9        3007370.0  \nZNAPS is a magnetic adapter specially design...
# 10       6333295.0  \nYu Suzuki presents the long awaited third in...
# 11      10266845.0  \nPebble is a customizable watch. Download new...
# ...

# %%
kick_data.describe()
# Out:
# //anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        pledged_amount          goal        backers    num_tiers
# count    4.000000e+03  4.000000e+03    4000.000000  3438.000000
# mean     2.899923e+05  6.175203e+04    3582.875750    14.598313
# std      7.119369e+05  1.266715e+05    7316.102809    10.200610
# min      1.925000e+03  1.000000e+00    1109.000000     1.000000
# 25%      6.771300e+04  1.300000e+04    1406.750000          NaN
# 50%      1.205860e+05  3.000000e+04    1946.000000          NaN
# 75%      2.593680e+05  6.000000e+04    3372.000000          NaN
# max      2.033899e+07  2.000000e+06  219382.000000   101.000000

# %%
kick_data.category.value_counts(ascending = False).head(25)
# Out:
# Product Design      773
# Tabletop Games      742
# Video Games         524
# Hardware            182
# Technology          152
# Documentary         124
# Gadgets             121
# Design               99
# Comics               79
# Wearables            64
# Fashion              61
# Animation            49
# Food                 46
# DIY Electronics      42
# Music                41
# Film &amp; Video     40
# Games                37
# Art Books            34
# Webcomics            33
# Apparel              32
# Webseries            32
# Software             27
# Camera Equipment     26
# Sound                26
# Narrative Film       25
# Name: category, dtype: int64

# %%
campaign_city = kick_data.pivot_table(index=['title', 'location', 'category'])
pd.DataFrame(campaign_city)
campaign_city
# Out:
#                                                                                                  backers  \
# title                                              location                   category
#  SAVE Blue Like Jazz! (the movie)                  Nashville, TN              Narrative Film      4495.0
# "All-American Boy" - The Album                     Chicago, IL                Rock                4905.0
# "Be Here Now" \u2013 The Andy Whitfield Story      Sydney, AU                 Documentary         5265.0
# "Bohemia" Playing Cards Deck                       Chicago, IL                Tabletop Games      1530.0
# "CINEMETROPOLIS": BLUE SCHOLARS SIGNS TO THE PE... Seattle, WA                Hip-Hop             2243.0
# "Chug" from the team that brought you "Three Sh... Los Angeles, CA            Film &amp; Video    8177.0
# "EARTHWARD" - Join the search!                     Los Angeles, CA            Comics              1503.0
# ...

# %%
chi_table = campaign_city.query('location == ["Chicago, IL"]',)
chi_table.head()
# Out:
#                                                                                backers  \
# title                                              location    category
# "All-American Boy" - The Album                     Chicago, IL Rock             4905.0
# "Bohemia" Playing Cards Deck                       Chicago, IL Tabletop Games   1530.0
# "Finding Vivian Maier" - a feature length docum... Chicago, IL Documentary      1495.0
# A Chaotic Life! - A Hectic & Strategic Game of ... Chicago, IL Tabletop Games   2423.0
# A Goose That Lays Golden Eggs                      Chicago, IL Food             5514.0
#
#                                                                                   goal  \
# title                                              location    category
# "All-American Boy" - The Album                     Chicago, IL Rock            81000.0
# "Bohemia" Playing Cards Deck                       Chicago, IL Tabletop Games  11000.0
# ...

# %%
LA_table = campaign_city.query('location == ["Los Angeles, CA"]')
LA_table
# Out:
#                                                                                      backers  \
# title                                              location        category
# "Chug" from the team that brought you "Three Sh... Los Angeles, CA Film &amp; Video   8177.0
# "EARTHWARD" - Join the search!                     Los Angeles, CA Comics             1503.0
# "Fallout: Nuka Break" Season 2                     Los Angeles, CA Webseries          1991.0
# "For the Love of Spock" - A Documentary Film       Los Angeles, CA Documentary        9439.0
# "Period of Comfort"                                Los Angeles, CA Ready-to-wear      1578.0
# "Period of Control"                                Los Angeles, CA Ready-to-wear      1248.0
# "Period of Happiness"                              Los Angeles, CA Ready-to-wear      3331.0
# "UNDER THE SMOGBERRY TREES: The True Story of D... Los Angeles, CA Documentary        1764.0
# ...

# %%
kick_data.groupby(['title', 'pitch', 'by', 'category'], axis=1)

# %%
text_table = kick_data.pivot_table(index=['title', 'pitch', 'by', 'category'])
text_table = pd.DataFrame(text_table)
text_table
# Out:
#                                                                                                                                                                   backers  \
# title                                              pitch                                              by                                       category
#  SAVE Blue Like Jazz! (the movie)                  \nA feature film based on Donald Miller's New Y... Steve Taylor                             Narrative Film        4495
# "All-American Boy" - The Album                     \nKeep the music/message pure. Be my "label" an... Steve Grand                              Rock                  4905
# "Be Here Now" \u2013 The Andy Whitfield Story      \nOPENING IN THE US APRIL 8TH!  For more info &... Lilibet Foster                           Documentary           5265
# ...

# %%
text_table['Percent_Funded'] = text_table.pledged_amount / text_table.goal
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-170-b74df318e755> in <module>()
# ----> 1 text_table['Percent_Funded'] = text_table.pledged_amount / text_table.goal
#
# //anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'pledged_amount'

# %%
text_table
# Out:
#                                                                                                                                                                   backers  \
# title                                              pitch                                              by                                       category
#  SAVE Blue Like Jazz! (the movie)                  \nA feature film based on Donald Miller's New Y... Steve Taylor                             Narrative Film        4495
# "All-American Boy" - The Album                     \nKeep the music/message pure. Be my "label" an... Steve Grand                              Rock                  4905
# "Be Here Now" \u2013 The Andy Whitfield Story      \nOPENING IN THE US APRIL 8TH!  For more info &... Lilibet Foster                           Documentary           5265
# ...

# %%
#create a new data frame

# %%
kick_data.head()
# Out:
#    pledged_amount                                              pitch  \
# 0       8782571.0  \nThis is a card game for people who are into ...
# 1       6465690.0  \nAn unusually addicting, high-quality desk to...
# 2       5408916.0  \nBring Reading Rainbow’s library of interacti...
# 3       5702153.0  \nUPDATED: This is it. We're making a Veronica...
# 4       3336371.0  \nAn adventure game from Tim Schafer, Double F...
#
#                                      by        category currency       goal  \
# 0                              Elan Lee  Tabletop Games      usd    10000.0
# 1            Matthew and Mark McLachlan  Product Design      usd    15000.0
# 2        LeVar Burton & Reading Rainbow             Web      usd  1000000.0
# 3                            Rob Thomas  Narrative Film      usd  2000000.0
# 4  Double Fine and 2 Player Productions     Video Games      usd   400000.0
#
#             location  backers  \
# 0    Los Angeles, CA   219382
# ...

# %%
kick_data.columns
# Out:
# Index([u'pledged_amount', u'pitch', u'by', u'category', u'currency', u'goal',
#        u'location', u'backers', u'backers_by_tier', u'pledge_tier', u'title',
#        u'url', u'num_tiers'],
#       dtype='object')

# %%
kick_data.drop([u'currency', u'backers_by_tier', u'pledge_tier', u'url'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-179-d64e414c21c6> in <module>()
# ----> 1 kick_data.drop([u'currency', u'backers_by_tier', u'pledge_tier', u'url'])
#
# //anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    1875                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1876             else:
# -> 1877                 new_axis = axis.drop(labels, errors=errors)
#    1878             dropped = self.reindex(**{axis_name: new_axis})
#    1879             try:
#
# //anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in drop(self, labels, errors)
#    3049             if errors != 'ignore':
#    3050                 raise ValueError('labels %s not contained in axis' %
# -> 3051                                  labels[mask])
# ...

# %%
type(kick_data.pledge_tier)
# Out:
# pandas.core.series.Series
